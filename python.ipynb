# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankitkumar18412/Student-Management-System/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image, display

# Step 1: Image link
image_url = "https://files.realpython.com/media/Operator-and-Function-Overloading-in-Custom-Python-Classes_Watermarked.575229f93a74.jpg"

# Step 2: Show image
display(Image(url=image_url, width=500, height=300))

# Step 3: Manually list items
items = [
    "Python logo",
    "def keyword",
    "len",
    "abs",
    "add",
    "sub",
    "mul",
    "self box",
    "other box",
    "return word",
    "Person holding paper",
    "Green board/screen",
    "Real Python logo",
    "Machine structure connecting blocks"
]


print("Items visible in the image:")
for i in items:
    print("-", i)
# Out:
# <img src="https://files.realpython.com/media/Operator-and-Function-Overloading-in-Custom-Python-Classes_Watermarked.575229f93a74.jpg" width="500" height="300"/>
# Items visible in the image:
# - Python logo
# - def keyword
# - len
# - abs
# - add
# - sub
# - mul
# - self box
# - other box
# - return word
# - Person holding paper
# - Green board/screen
# - Real Python logo
# - Machine structure connecting blocks
